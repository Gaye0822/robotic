# %%
import gymnasium as gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy 
import os

# %%
env_name='Pusher-v5'
env =gym.make(env_name,render_mode="human")

# %%
episodes=5
for episode in range(1,episodes+1):
    obs=env.reset()
    done=False
    score=0
    while not done:
        env.render()
        action=env.action_space.sample()
        obs,reward,done, _,info=env.step(action)
        score+=reward
    print('episode:{} score{}'.format(episode,score))
          
env.close()
# Out:
# 2024-11-07 20:47:07.799 Python[25616:4299250] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 score=0
#       6 while not done:
# ----> 7     env.render()
#       8     action=env.action_space.sample()
#       9     obs,reward,done, _,info=env.step(action)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/core.py:332, in Wrapper.render(self)
#     330 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     331     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 332     return self.env.render()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/wrappers/common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/core.py:332, in Wrapper.render(self)
#     330 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     331     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 332     return self.env.render()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/wrappers/common.py:303, in PassiveEnvChecker.render(self)
#     301     return env_render_passive_checker(self.env)
#     302 else:
# --> 303     return self.env.render()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/envs/mujoco/mujoco_env.py:165, in MujocoEnv.render(self)
#     161 def render(self):
#     162     """
#     163     Render a frame from the MuJoCo simulation as specified by the render_mode.
#     164     """
# --> 165     return self.mujoco_renderer.render(self.render_mode)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:723, in MujocoRenderer.render(self, render_mode)
#     721     return viewer.render(render_mode=render_mode, camera_id=self.camera_id)
#     722 elif render_mode == "human":
# --> 723     return viewer.render()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:445, in WindowViewer.render(self)
#     443         self._loop_count = 1
#     444     while self._loop_count > 0:
# --> 445         update()
#     446         self._loop_count -= 1
#     448 # clear overlay
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:417, in WindowViewer.render.<locals>.update()
#     415 if not self._hide_menu:
#     416     for gridpos, [t1, t2] in self._overlays.items():
# --> 417         mujoco.mjr_overlay(
#     418             mujoco.mjtFontScale.mjFONTSCALE_150,
#     419             gridpos,
#     420             self.viewport,
#     421             t1,
#     422             t2,
#     423             self.con,
#     424         )
#     426 glfw.swap_buffers(self.window)
#     427 glfw.poll_events()
#
# KeyboardInterrupt:

# %%
env.action_space
# Out:
# Box(-2.0, 2.0, (7,), float32)

# %%
env.observation_space
# Out:
# Box(-inf, inf, (23,), float64)

# %%
log_path=os.path.join('Trainig','Logs')
model =PPO('MlpPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
os.makedirs(log_path, exist_ok=True)

# %%
model.learn(total_timesteps=1000000)
# Out:
# Logging to Trainig/Logs/PPO_4
# 2024-11-08 07:38:59.017 Python[28288:4389526] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -122     |
# | time/              |          |
# |    fps             | 59       |
# |    iterations      | 1        |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 2           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013347901 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.89       |
# |    explained_variance   | -0.012      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.99        |
# |    value_loss           | 171         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 3           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010812042 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.82       |
# |    explained_variance   | -0.00434    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.978       |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -118        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 4           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011453582 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.74       |
# |    explained_variance   | 0.00689     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.97        |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 5           |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012945519 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.67       |
# |    explained_variance   | -0.00382    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.957       |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -115        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 6           |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011535148 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.57       |
# |    explained_variance   | -0.00325    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.944       |
# |    value_loss           | 86.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 7           |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011427019 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.47       |
# |    explained_variance   | -0.000896   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.931       |
# |    value_loss           | 59.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -112       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 8          |
# |    time_elapsed         | 277        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01326403 |
# |    clip_fraction        | 0.128      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.37      |
# |    explained_variance   | -0.000655  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.78       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0193    |
# |    std                  | 0.917      |
# |    value_loss           | 47.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 9           |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015286896 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.23       |
# |    explained_variance   | -0.000649   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.8         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.895       |
# |    value_loss           | 32.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 10          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018133365 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.05       |
# |    explained_variance   | -0.000759   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.871       |
# |    value_loss           | 22.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 11          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.023700308 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.87       |
# |    explained_variance   | 0.00199     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.849       |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 12          |
# |    time_elapsed         | 416         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018128721 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.72       |
# |    explained_variance   | 0.0101      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.829       |
# |    value_loss           | 7.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -98.9       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 13          |
# |    time_elapsed         | 451         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.017931286 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.52       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.807       |
# |    value_loss           | 3.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -96.7       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 14          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016227119 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.33       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.51        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.789       |
# |    value_loss           | 2.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -93.9       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 15          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.019048274 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.12       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.656       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0315     |
# |    std                  | 0.763       |
# |    value_loss           | 1.63        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -91.1      |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 16         |
# |    time_elapsed         | 555        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01579962 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -7.92      |
# |    explained_variance   | 0.473      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.474      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0272    |
# |    std                  | 0.744      |
# |    value_loss           | 1.26       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -88.9       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 17          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016282499 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.74       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.347       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.724       |
# |    value_loss           | 0.978       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -86         |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 18          |
# |    time_elapsed         | 624         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015602058 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.58       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.308       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0311     |
# |    std                  | 0.71        |
# |    value_loss           | 0.984       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -83.7       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 19          |
# |    time_elapsed         | 659         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.017019384 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.45       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.452       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0313     |
# |    std                  | 0.697       |
# |    value_loss           | 1.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -81.5       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 20          |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017861186 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.29       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.251       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.68        |
# |    value_loss           | 0.876       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -78.9       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 21          |
# |    time_elapsed         | 729         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.014519727 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.11       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.301       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.661       |
# |    value_loss           | 0.881       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -76.8       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 22          |
# |    time_elapsed         | 763         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018124778 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.92       |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.286       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0299     |
# |    std                  | 0.644       |
# |    value_loss           | 0.806       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -75        |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 23         |
# |    time_elapsed         | 798        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01569613 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.75      |
# |    explained_variance   | 0.547      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.366      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0251    |
# |    std                  | 0.629      |
# |    value_loss           | 0.891      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -72.7       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 24          |
# |    time_elapsed         | 833         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016681533 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.56       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.336       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.611       |
# |    value_loss           | 0.825       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -70.5       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 25          |
# |    time_elapsed         | 868         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014235196 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.42       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.601       |
# |    value_loss           | 0.651       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -69.1       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 26          |
# |    time_elapsed         | 902         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015975442 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.29       |
# |    explained_variance   | 0.552       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.228       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.591       |
# |    value_loss           | 0.762       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -67.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 27          |
# |    time_elapsed         | 937         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.014869511 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.17       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.323       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.579       |
# |    value_loss           | 0.731       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -65.5       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 28          |
# |    time_elapsed         | 972         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015197804 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.03       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.569       |
# |    value_loss           | 0.444       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -64.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 29          |
# |    time_elapsed         | 1006        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014759357 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.92       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.171       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.56        |
# |    value_loss           | 0.655       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -63.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 30          |
# |    time_elapsed         | 1041        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.015767269 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.8        |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.55        |
# |    value_loss           | 0.488       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -62.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 31          |
# |    time_elapsed         | 1076        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.017203353 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.539       |
# |    value_loss           | 0.462       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -61.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 32          |
# |    time_elapsed         | 1111        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016290307 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.5        |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.527       |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -60.8       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 33          |
# |    time_elapsed         | 1145        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016419075 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.221       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.517       |
# |    value_loss           | 0.533       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -59         |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 34          |
# |    time_elapsed         | 1180        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016150909 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.22       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0673      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.506       |
# |    value_loss           | 0.279       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -58.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 35          |
# |    time_elapsed         | 1215        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014559172 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.08       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.135       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.496       |
# |    value_loss           | 0.484       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -57.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 36          |
# |    time_elapsed         | 1250        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017333616 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.94       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.486       |
# |    value_loss           | 0.357       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -56.7       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 37          |
# |    time_elapsed         | 1284        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.016462706 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.79       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0641      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.475       |
# |    value_loss           | 0.319       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -55.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 38          |
# |    time_elapsed         | 1319        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.017061468 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.65       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.466       |
# |    value_loss           | 0.413       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -54.5       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 39          |
# |    time_elapsed         | 1354        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.017009936 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.129       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.46        |
# |    value_loss           | 0.336       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 40          |
# |    time_elapsed         | 1388        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015083082 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.451       |
# |    value_loss           | 0.375       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -52.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 41          |
# |    time_elapsed         | 1423        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.023255043 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0496      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.443       |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -51.9       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 42          |
# |    time_elapsed         | 1458        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.014882544 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.436       |
# |    value_loss           | 0.384       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -51.8       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 43          |
# |    time_elapsed         | 1493        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.015948929 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.101       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.432       |
# |    value_loss           | 0.261       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -51.5       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 44          |
# |    time_elapsed         | 1527        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.021447822 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0824      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.423       |
# |    value_loss           | 0.273       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -51.1       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 45          |
# |    time_elapsed         | 1562        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013178012 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.199       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.418       |
# |    value_loss           | 0.502       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -50.7       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 46          |
# |    time_elapsed         | 1597        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017846147 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0986      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.41        |
# |    value_loss           | 0.307       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 47          |
# |    time_elapsed         | 1632        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017341983 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0584      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.403       |
# |    value_loss           | 0.225       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -49.1       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 48          |
# |    time_elapsed         | 1666        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.017766394 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0558      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.392       |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -48.4       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 49          |
# |    time_elapsed         | 1701        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017530039 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.128       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.384       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -47.7      |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 50         |
# |    time_elapsed         | 1736       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01906044 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.157      |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0138    |
# |    std                  | 0.377      |
# |    value_loss           | 0.343      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -47.3       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 51          |
# |    time_elapsed         | 1770        |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.014681445 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0527      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.371       |
# |    value_loss           | 0.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -47.2       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 52          |
# |    time_elapsed         | 1805        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.017952379 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.149       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.366       |
# |    value_loss           | 0.367       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -46.6       |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 53          |
# |    time_elapsed         | 1840        |
# ...
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.92        |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0538      |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.0035     |
# |    std                  | 0.121       |
# |    value_loss           | 0.249       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -33         |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 473         |
# |    time_elapsed         | 15899       |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.033502996 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.89        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0306      |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.00865    |
# |    std                  | 0.121       |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -33         |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 474         |
# |    time_elapsed         | 15900       |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.028972736 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.9         |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.113       |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.00611    |
# |    std                  | 0.121       |
# |    value_loss           | 0.249       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -33.1      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 475        |
# |    time_elapsed         | 15901      |
# |    total_timesteps      | 972800     |
# | train/                  |            |
# |    approx_kl            | 0.03154403 |
# |    clip_fraction        | 0.36       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.91       |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0394     |
# |    n_updates            | 4740       |
# |    policy_gradient_loss | -0.0101    |
# |    std                  | 0.121      |
# |    value_loss           | 0.232      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -33.1      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 476        |
# |    time_elapsed         | 15901      |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.03012082 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.92       |
# |    explained_variance   | 0.978      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0875     |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.00288   |
# |    std                  | 0.121      |
# |    value_loss           | 0.232      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -32.7      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 477        |
# |    time_elapsed         | 15902      |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.03553268 |
# |    clip_fraction        | 0.353      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.95       |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0537     |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.00843   |
# |    std                  | 0.12       |
# |    value_loss           | 0.156      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -32.8      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 478        |
# |    time_elapsed         | 15903      |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.04464782 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.97       |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.128      |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.0128    |
# |    std                  | 0.12       |
# |    value_loss           | 0.411      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.8       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 479         |
# |    time_elapsed         | 15903       |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.028940463 |
# |    clip_fraction        | 0.319       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.98        |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0978      |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00367    |
# |    std                  | 0.12        |
# |    value_loss           | 0.284       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.8       |
# | time/                   |             |
# |    fps                  | 61          |
# |    iterations           | 480         |
# |    time_elapsed         | 15904       |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.025117513 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.95        |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0555      |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0063     |
# |    std                  | 0.12        |
# |    value_loss           | 0.446       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 100      |
# |    ep_rew_mean          | -33      |
# | time/                   |          |
# |    fps                  | 61       |
# |    iterations           | 481      |
# |    time_elapsed         | 15905    |
# |    total_timesteps      | 985088   |
# | train/                  |          |
# |    approx_kl            | 0.0325   |
# |    clip_fraction        | 0.31     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 4.91     |
# |    explained_variance   | 0.972    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.208    |
# |    n_updates            | 4800     |
# |    policy_gradient_loss | -0.00667 |
# |    std                  | 0.121    |
# |    value_loss           | 0.333    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | -33.1      |
# | time/                   |            |
# |    fps                  | 62         |
# |    iterations           | 482        |
# |    time_elapsed         | 15905      |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.03348379 |
# |    clip_fraction        | 0.28       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 4.88       |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0988     |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.00901   |
# |    std                  | 0.121      |
# |    value_loss           | 0.856      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -33.7       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 483         |
# |    time_elapsed         | 15906       |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.033055276 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.88        |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.45        |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00482    |
# |    std                  | 0.121       |
# |    value_loss           | 0.848       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -33.4       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 484         |
# |    time_elapsed         | 15907       |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.037516315 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.89        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.26        |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.121       |
# |    value_loss           | 0.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -33.3       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 485         |
# |    time_elapsed         | 15907       |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.030869128 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.91        |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | 0.00281     |
# |    std                  | 0.121       |
# |    value_loss           | 0.286       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -33         |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 486         |
# |    time_elapsed         | 15908       |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.034167424 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.89        |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.357       |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.00949    |
# |    std                  | 0.121       |
# |    value_loss           | 0.789       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.7       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 487         |
# |    time_elapsed         | 15908       |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.040562242 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.89        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0658      |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00289    |
# |    std                  | 0.121       |
# |    value_loss           | 0.271       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.3       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 488         |
# |    time_elapsed         | 15909       |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.038298428 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.91        |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.0068     |
# |    std                  | 0.121       |
# |    value_loss           | 0.535       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -32.4       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 489         |
# |    time_elapsed         | 15910       |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.028509943 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 4.91        |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.244       |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.00719    |
# |    std                  | 0.121       |
# |    value_loss           | 1.12        |
# -----------------------------------------

# %%
from stable_baselines3.common.monitor import Monitor

# %%
env = Monitor(env)

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean Reward: {mean_reward}, Std: {std_reward}")
# Out:
# Mean Reward: -31.099137000000002, Std: 6.539724419999271

# %%
ppo_path=os.path.join('Trainig','Saved_Model','PPO_pusher_model_4')

# %%
model.save(ppo_path)

# %%
del model

# %%
model=PPO.load(ppo_path,env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
evaluate_policy(model,env,n_eval_episodes=5, render=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 2024-11-08 12:11:27.573 Python[28803:4514026] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# (-52.47411552071571, 2.192568791847386)

# %%
episodes=5
for episode in range(1,episodes+1):
    reset_result = env.reset()
    obs = reset_result[0] if isinstance(reset_result, tuple) else reset_result
    done=False
    score=0
    while not done:
        env.render()
        action, _=model.predict(obs)
        obs,reward,done, _,info=env.step(action)
        score+=reward
    print('episode:{} score: {}'.format(episode,score))
env.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 10
#       8     env.render()
#       9     action, _=model.predict(obs)
# ---> 10     obs,reward,done, _,info=env.step(action)
#      11     score+=reward
#      12 print('episode:{} score: {}'.format(episode,score))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/monitor.py:93, in Monitor.step(self, action)
#      86 """
#      87 Step the environment with the given action
#      88
#      89 :param action: the action
#      90 :return: observation, reward, terminated, truncated, information
#      91 """
#      92 if self.needs_reset:
# ---> 93     raise RuntimeError("Tried to step environment that needs reset")
#      94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#
# RuntimeError: Tried to step environment that needs reset
